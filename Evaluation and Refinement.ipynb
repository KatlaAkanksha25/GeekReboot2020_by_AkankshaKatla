# %% [markdown]
# # Description
#
# This notebook is used to process and evalutate the initial universe of generated smiles, and then retain the network applying techniques and principles from both transfer learning and genetic algorithms to increasingly improve molecule generation for the specific task of binding with cornovirus protease.

# %% [markdown]
# ## First process initial generated smiles for PyRx analysis

# %%
import pandas as pd
from rdkit import Chem, DataStructs
import random
import numpy as np
import rdkit.Chem.PropertyMol
import rdkit.Chem.Descriptors

# %%
gen0_table = pd.read_csv('./generations/gen0_smiles.smi',sep=',', header=None)
gen0 = list(gen0_table[0])[0:10000]
len(gen0)
# Out:
# 9703

# %%
def validate_mols(list_of_smiles):
    valid_mols = []
    for smi in list_of_smiles:
        mol = Chem.MolFromSmiles(smi)
        if mol is not None:
            valid_mols.append(mol)
    return valid_mols

def convert_mols_to_smiles(list_of_mols):
    valid_smiles = [Chem.MolToSmiles(mol) for mol in list_of_mols]
    return valid_smiles

# %%
gen0_mols = validate_mols(gen0)
len(gen0_mols)
# Out:
# 9703

# %%
'''Intakes a list of smiles, randomly shuffles them, then adds first thirty,
then sets a max-similarity threshold between any new molecule and existing list
and iteratively increases the treshold until X components are picked to ensure diveristy'''

def initialize_generation_from_mols(list_of_mols,desired_length):  
    assert desired_length >30
    random.shuffle(list_of_mols)
    random.shuffle(list_of_mols)
    
    #Prepare fingerprints for similarity calcs
    mol_fingerprints = []
    for mol in list_of_mols:
        mol_fingerprints.append(Chem.RDKFingerprint(mol))
    
    selected_mols = list_of_mols[0:30]
    selected_fingerprints = mol_fingerprints[0:30]
    remaining_mols = list_of_mols[30:]
    remaining_fingerprints = mol_fingerprints[30:]
    
    similarity_threshold = .05   
    while len(selected_mols) < desired_length:
        for fingerprint, mol in zip(remaining_fingerprints, remaining_mols):
            max_similarity = np.max(DataStructs.BulkTanimotoSimilarity(fingerprint,selected_fingerprints))
            if (max_similarity <= similarity_threshold) and (max_similarity < 1):
                selected_fingerprints.append(fingerprint)
                selected_mols.append(mol)
        print("Completed loop with threshold at: ", similarity_threshold, ". Length is currently: ", len(selected_mols))
        similarity_threshold += .05
    return selected_mols

# %%
gen0_mols = initialize_generation_from_mols(gen0_mols,1000)
print(len(gen0_mols))
# Out:
# Completed loop with threshold at:  0.05 . Length is currently:  30
# Completed loop with threshold at:  0.1 . Length is currently:  32
# Completed loop with threshold at:  0.15000000000000002 . Length is currently:  33
# Completed loop with threshold at:  0.2 . Length is currently:  39
# Completed loop with threshold at:  0.25 . Length is currently:  72
# Completed loop with threshold at:  0.3 . Length is currently:  201
# Completed loop with threshold at:  0.35 . Length is currently:  528
# Completed loop with threshold at:  0.39999999999999997 . Length is currently:  1132
# 1132

# %%
master_table = pd.read_csv('./generations/master_results_table.csv',sep=',')
master_table.shape[0]
# Out:
# 9354

# %%
'''Certainly not opimized and not strictly necessary, but in the PyRx GUI
molecule names would sort oddly when in any numeric order, so ordering
molcules by a four letter code. This function iterates the four letter code.'''
def iterate_alpha(alpha_code):
    numbers = []
    for letter in alpha_code:
        number = ord(letter)
        numbers.append(number)
    
    if numbers[3]+1 > 90:
        if numbers[2]+1 > 90:
            if numbers[1]+1 > 90:
                if numbers[0]+1 > 90:
                    raise ValueError('Too long for alpha code')
                else:
                    numbers[3] = 65
                    numbers[2] = 65
                    numbers[1] = 65
                    numbers[0] = numbers[0] + 1
            else:
                numbers[3] = 65
                numbers[2] = 65
                numbers[1] = numbers[1] + 1
        else:
            numbers[3] = 65
            numbers[2] = numbers[2] + 1
    else:
        numbers[3] = numbers[3] + 1
    

    new_code = ""
    for number in numbers:
        new_code += chr(number)
    return new_code
iterate_alpha('AAAA')
# Out:
# 'AAAB'

# %%
def append_to_tracking_table(master_table,mols_to_append, source, generation):
    # Assign IDs for tracking to each mol, and assign a pandas table entry for each
    mols_to_export = []
    rows_list = []
    
    master_table_gen = master_table[master_table['gen'] == generation]
    if master_table_gen.shape[0] == 0:
        id_code = 'AAAA'
    else:
        master_table_gen_ids = master_table_gen.sort_values('id', ascending=True)
        master_table_gen_max_id = master_table_gen_ids.tail(1)
        key = master_table_gen_max_id['id'].keys()[0]
        id_code = iterate_alpha(str(master_table_gen_max_id['id'][key]))
        
    training_data = pd.read_csv('./datasets/all_smiles_clean.smi', header=None)
    training_set = set(list(training_data[0]))
    
    for mol in mols_to_append:
        pm = Chem.PropertyMol.PropertyMol(mol)
        title = 'id' + str(id_code) + 'gen'+ str(generation)
        print(title)
        # Enables for tracking which molecule is which in PyRx GUI and PyRx results export
        pm.SetProp('Title', title)
        mols_to_export.append(pm)

        #And track in pandas
        mol_dict = {}
        mol_dict['id'] = id_code
        mol_dict['gen'] = generation
        smile = Chem.MolToSmiles(mol)
        assert type(smile) == type('string')
        mol_dict['smile'] = smile

        if (source!= 'hiv' and source != 'manual' and source != 'baseline') and (smile in training_set):
            mol_dict['source'] = 'training'
        else:
            mol_dict['source'] = source
        mol_dict['score'] = 99.9

        rows_list.append(mol_dict)
        id_code = iterate_alpha(id_code)
        
    df = pd.DataFrame(rows_list)
    return df, mols_to_export

# %%
new_mols_to_test = append_to_tracking_table(master_table,gen0_mols, 'generated', 0)
mols_for_pd = new_mols_to_test[0]
mols_for_export = new_mols_to_test[1]
master_table = master_table.append(mols_for_pd)
len(mols_for_export)
# Out:
# idANVUgen0
# idANVVgen0
# idANVWgen0
# idANVXgen0
# idANVYgen0
# idANVZgen0
# idANWAgen0
# idANWBgen0
# idANWCgen0
# idANWDgen0
# idANWEgen0
# idANWFgen0
# idANWGgen0
# idANWHgen0
# idANWIgen0
# idANWJgen0
# idANWKgen0
# idANWLgen0
# idANWMgen0
# idANWNgen0
# idANWOgen0
# idANWPgen0
# idANWQgen0
# idANWRgen0
# idANWSgen0
# idANWTgen0
# idANWUgen0
# idANWVgen0
# idANWWgen0
# idANWXgen0
# idANWYgen0
# idANWZgen0
# idANXAgen0
# idANXBgen0
# idANXCgen0
# idANXDgen0
# idANXEgen0
# idANXFgen0
# idANXGgen0
# idANXHgen0
# idANXIgen0
# idANXJgen0
# idANXKgen0
# idANXLgen0
# idANXMgen0
# idANXNgen0
# idANXOgen0
# idANXPgen0
# idANXQgen0
# idANXRgen0
# idANXSgen0
# idANXTgen0
# idANXUgen0
# idANXVgen0
# idANXWgen0
# idAPIJgen0
# idAPIKgen0
# idAPILgen0
# idAPIMgen0
# idAPINgen0
# idAPIOgen0
# idAPIPgen0
# idAPIQgen0
# idAPIRgen0
# idAPISgen0
# idAPITgen0
# idAPIUgen0
# idAPIVgen0
# idAPIWgen0
# idAPIXgen0
# idAPIYgen0
# idAPIZgen0
# idAPJAgen0
# idAPJBgen0
# idAPJCgen0
# idAPJDgen0
# idAPJEgen0
# idAPJFgen0
# idAPJGgen0
# idAPJHgen0
# idAPJIgen0
# idAPJJgen0
# idAPJKgen0
# idAPJLgen0
# idAPJMgen0
# idAPJNgen0
# idAPJOgen0
# idAPJPgen0
# idAPJQgen0
# idAPJRgen0
# idAPJSgen0
# idAPJTgen0
# idAPJUgen0
# idAPJVgen0
# idAPJWgen0
# idAPJXgen0
# idAPJYgen0
# idAPJZgen0
# idAPKAgen0
# idAPKBgen0
# idAPKCgen0
# idAPKDgen0
# idAPKEgen0
# idAPKFgen0
# idAPKGgen0
# idAPKHgen0
# idAPKIgen0
# idAPKJgen0
# idAPKKgen0
# idAPKLgen0
# idAPKMgen0
# idAPKNgen0
# idAPKOgen0
# idAPKPgen0
# idAPKQgen0
# idAPKRgen0
# idAPKSgen0
# idAPKTgen0
# idAPKUgen0
# idAPKVgen0
# idAPKWgen0
# idAPKXgen0
# idAPKYgen0
# idAPKZgen0
# idAPLAgen0
# idAPLBgen0
# idAPLCgen0
# idAPLDgen0
# idAPLEgen0
# idAPLFgen0
# idAPLGgen0
# idAPLHgen0
# idAPLIgen0
# idAPLJgen0
# idAPLKgen0
# idAPLLgen0
# idAPLMgen0
# idAPLNgen0
# idAPLOgen0
# idAPLPgen0
# idAPLQgen0
# idAPLRgen0
# idAPLSgen0
# idAPLTgen0
# idAPLUgen0
# idAPLVgen0
# idAPLWgen0
# idAPLXgen0
# idAPLYgen0
# idAPLZgen0
# idAPMAgen0
# idAPMBgen0
# idAPMCgen0
# idAPMDgen0
# idAPMEgen0
# idAPMFgen0
# idAPMGgen0
# idAPMHgen0
# idAPMIgen0
# idAPMJgen0
# idAPMKgen0
# idAPMLgen0
# idAPMMgen0
# idAPMNgen0
# idAPMOgen0
# idAPMPgen0
# idAPMQgen0
# idAPMRgen0
# idAPMSgen0
# idAPMTgen0
# idAPMUgen0
# idAPMVgen0
# idAPMWgen0
# idAPMXgen0
# idAPMYgen0
# idAPMZgen0
# idAPNAgen0
# idAPNBgen0
# idAPNCgen0
# idAPNDgen0
# idAPNEgen0
# idAPNFgen0
# idAPNGgen0
# idAPNHgen0
# 1132

# %%
master_table = master_table.reset_index(drop=True)
master_table.to_csv(r'./generations/master_results_table.csv', index=False)

# %%
# Add HIV inhibitors manually into the table
hiv_smiles = pd.read_csv('./datasets/hiv_inhibitors_cleaned.smi',sep=',', header=None)
hiv_smiles = list(hiv_smiles[0])
hiv_mols = validate_mols(hiv_smiles)

master_table = pd.read_csv('./generations/master_results_table.csv',sep=',')
new_mols_to_test = append_to_tracking_table(master_table,hiv_mols, 'hiv', 0)
mols_for_pd = new_mols_to_test[0]
mols_for_export = mols_for_export + new_mols_to_test[1]

master_table = master_table.append(mols_for_pd)
master_table = master_table.reset_index(drop=True)
master_table.to_csv(r'./generations/master_results_table.csv', index=False)
# Out:
# idAPNIgen0
# idAPNJgen0
# idAPNKgen0
# idAPNLgen0
# idAPNMgen0
# idAPNNgen0
# idAPNOgen0
# idAPNPgen0
# idAPNQgen0
# idAPNRgen0
# idAPNSgen0
# idAPNTgen0
# idAPNUgen0

# %%
# Add a few other smiles manually into the table ("control group" of training smiles)
manual_smiles = pd.read_csv('./datasets/manual_testing_cleaned.smi',sep=',', header=None)
manual_smiles = list(manual_smiles[0])
manual_mols = validate_mols(hiv_smiles)

master_table = pd.read_csv('./generations/master_results_table.csv',sep=',')
new_mols_to_test = append_to_tracking_table(master_table,manual_mols, 'manual', 0)
mols_for_pd = new_mols_to_test[0]
mols_for_export = mols_for_export + new_mols_to_test[1]

master_table = master_table.append(mols_for_pd)
master_table = master_table.reset_index(drop=True)
master_table.to_csv(r'./generations/master_results_table.csv', index=False)
# Out:
# idAPNVgen0
# idAPNWgen0
# idAPNXgen0
# idAPNYgen0
# idAPNZgen0
# idAPOAgen0
# idAPOBgen0
# idAPOCgen0
# idAPODgen0
# idAPOEgen0
# idAPOFgen0
# idAPOGgen0
# idAPOHgen0

# %%
def write_gen_to_sdf(mols_for_export, generation, batch_size):
    if len(mols_for_export) > batch_size:
        batches = (len(mols_for_export) // 1000)+1
        for i in range(0,batches):
            batch_to_export = mols_for_export[i*batch_size:(i+1)*batch_size]
            w = Chem.SDWriter('./generations/gen' +str(generation) + '_batch_' + str(i+1) + '.sdf')
            for m in batch_to_export: w.write(m)
    else:
        w = Chem.SDWriter('./generations/gen' +str(generation) + '.sdf')
        for m in mols_for_export:
            w.write(m)
    
    # Noticed an issue where the very last line item of an sdf write is not written correctly until another arbitary write is made
    w = Chem.SDWriter('./generations/junk/test.sdf')
    w.write(m)
    
    return mols_for_export

# %%
write_gen_to_sdf(mols_for_export, 0, 2000)
print('ok')
# Out:
# ok

# %% [markdown]
# ## NOW GO TO PyRx: Analyze the SDF file and create a csv of binding score results

# %% [markdown]
# ## Afterwards, process binding simulation results to 'evolve' the molecules

# %%
'''This number must be MANUALLY iterated each generation. I did not write the entire process into a smooth function or loop but that would be the next steps.''' 
GLOBAL_GENERATION = 11

# %%
master_table = pd.read_csv('./generations/master_results_table_gen' + str(GLOBAL_GENERATION-1) + '.csv',sep=',')
master_table.tail()
# Out:
#         id  gen                                              smile     source  \
# 3015  AAAM   10  O=C(O)C(Cc1ccccc1)NC(=O)C(Cc1ccccc1)NC(=O)C1C2...  generated
# 3016  AAAO   10  O=C(NC1CC2CCCC(C1)N2CCc1ccccc1)C1CC2CC(C1)C2C(...  generated
# 3017  AABB    0                     Cc1noc(CCCn2ccc(CN3CCCC3)n2)n1  generated
# 3018  AAJU    0               COc1ccc(NC(=O)C(O)C(C)N2CCOCC2)cc1Cl  generated
# 3019  AACU    7  O=CC(Cc1ccccc1)NC(=O)C(Cc1ccccc1)NC(=O)C(Cc1cc...  generated
#
#         weight  score
# 3015   625.722   99.9
# 3016   704.912   99.9
# 3017   275.356   99.9
# 3018   328.796   99.9
# 3019  1049.326   99.9

# %%
new_scores = pd.read_csv('./generations/results/results_gen' + str(GLOBAL_GENERATION-1) + '.csv',sep=',')
new_scores.head()
# Out:
#              Ligand  Binding Affinity  rmsd/ub   rmsd/lb
# 0  6lu7_idAACHgen10             -12.3    0.000     0.000
# 1  6lu7_idAACHgen10             -11.2    8.180     1.483
# 2  6lu7_idAACHgen10             -10.6    5.671     2.828
# 3  6lu7_idAACHgen10             -10.3    5.683     2.447
# 4  6lu7_idAACHgen10             -10.2   15.747    14.575

# %%
new_scores = new_scores.groupby("Ligand").min()["Binding Affinity"].reset_index()
new_scores['id'] = new_scores['Ligand'].str.split("_").str[1].str.split("gen").str[0].str.split("id").str[1]
new_scores['gen'] = new_scores['Ligand'].str.split("_").str[1].str.split("gen").str[1]
new_scores['score'] = new_scores["Binding Affinity"]
new_scores = new_scores[['id','gen','score']]
new_scores.head()
# Out:
#      id gen  score
# 0  AAAA  10  -14.9
# 1  AAAB  10  -10.5
# 2  AAAC  10  -16.3
# 3  AAAD  10  -12.4
# 4  AAAE  10  -11.9

# %%
new_scores.id = new_scores.id.astype(str)
new_scores.gen = new_scores.gen.astype(int)
master_table.id = master_table.id.astype(str)
master_table.gen = master_table.gen.astype(int)
new_table = pd.merge(master_table, new_scores, on=['id','gen'], suffixes=('_old','_new'), how='left')
new_table['score'] = np.where(new_table['score_new'].isnull(), new_table['score_old'], new_table['score_new'])
new_table = new_table.drop(['score_old','score_new'], axis=1)
new_table['weight'] = new_table['smile'].apply(lambda x: Chem.Descriptors.MolWt(Chem.MolFromSmiles(x)))
new_table = new_table.sort_values('score', ascending=True)
new_table.head()
# Out:
#      id  gen                                              smile     source  \
# 0  AABL   10  O=C(NC(Cc1ccccc1)C(=O)NC(Cc1ccccc1)C(=O)O)C1CC...  generated
# 1  AADG    9  O=C(NC1CC2CCC(C1)N2CCc1ccccc1)C1CC2CC(C1)C2C(=...  generated
# 2  AACA   10  O=C(NC1CC2CCC(C1)N2CCc1ccccc1)C1CC2CC(C1)C2C(=...  generated
# 3  AABO    9  O=C(NC1CC2CCC(C1)N2CCc1ccccn1)C1CC2CCC(C1)C2C(...  generated
# 4  AABK   10  O=C(NC1CC2CCC(C1)N2CCc1ccccn1)C1CC2CCC(C1)C2C(...  generated
#
#     weight  score
# 0  786.926  -17.9
# 1  838.062  -17.7
# 2  838.062  -17.7
# 3  853.077  -17.6
# 4  853.077  -17.6

# %%
new_table.to_csv(r'./generations/master_results_table_gen' + str(GLOBAL_GENERATION-1) + '.csv', index=False)

# %%
# Select top X ranked by score for training data to refine the molecule generator RNN
training_smiles = list(set(list(new_table.head(35)['smile'])))
len(training_smiles)
# Out:
# 21

# %%
training_fingerprints = []
for smile in training_smiles:
    training_fingerprints.append(Chem.RDKFingerprint(Chem.MolFromSmiles(smile)))

def calc_similarity_score(row):
    fingerprint = Chem.RDKFingerprint(Chem.MolFromSmiles(row['smile']))
    similarity = np.max(DataStructs.BulkTanimotoSimilarity(fingerprint,training_fingerprints))
    adj_factor = (1 / similarity) **.333
    adj_score = row['score'] * adj_factor
    return adj_score

similarity_adjusted = new_table.copy(deep=True)
similarity_adjusted = similarity_adjusted[similarity_adjusted['weight'] < 900]
similarity_adjusted['similarity_adj_score'] = similarity_adjusted.apply(calc_similarity_score, axis=1)
similarity_adjusted = similarity_adjusted.sort_values('similarity_adj_score', ascending=True)
similarity_adjusted.head()
# Out:
#        id  gen                                              smile     source  \
# 396  AAGJ    6  CC(C)(C)C1CCC(C2CCCCCC2(C)C)CCCC2(C)C(CCC3CCCC...  generated
# 198  AABP    5  CC1(CC(CC(O)C2(O)CCCC2)C(O)CO)CCCCCCCCCCCCCCCC...  generated
# 642  AAAE    7  CC1(C)CCCC2(C)C(CCC3CCCC3)CCCCCC(CCC3CCCC3)CCC...  generated
# 648  AAAL    7  CC(C)(C)C1CC2(C(C)(C)C)CCCC2(C)C1CCC12CC3CC(CC...  generated
# 649  AAAI    8  CC(C)(C)C1CC2(C(C)(C)C)CCCC2(C)C1CCC12CC3CC(CC...  generated
#
#       weight  score  similarity_adj_score
# 396  661.200  -11.5            -24.697105
# 198  763.286  -13.0            -23.467864
# 642  661.200  -10.3            -22.120016
# 648  398.719  -10.3            -21.819331
# 649  398.719  -10.3            -21.819331

# %%
# Select top X ranked by similarity adjusted score for training data to refine the molecule generator RNN (ensures diverity)
training_smiles += list(similarity_adjusted.head(5)['smile'])
len(training_smiles)
# Out:
# 26

# %%
def calc_weight_score(row):
    adj_factor = (900 / row['weight']) ** .333
    if adj_factor < 1:
        adj_score = 0
    else:
        adj_score = row['score'] * adj_factor
    return adj_score

weight_adjusted = new_table.copy(deep=True)
weight_adjusted['weight_adj_score'] = weight_adjusted.apply(calc_weight_score, axis=1)
weight_adjusted = weight_adjusted.sort_values('weight_adj_score', ascending=True)
weight_adjusted.head()
# Out:
#       id  gen                                              smile     source  \
# 0   AABL   10  O=C(NC(Cc1ccccc1)C(=O)NC(Cc1ccccc1)C(=O)O)C1CC...  generated
# 1   AADG    9  O=C(NC1CC2CCC(C1)N2CCc1ccccc1)C1CC2CC(C1)C2C(=...  generated
# 2   AACA   10  O=C(NC1CC2CCC(C1)N2CCc1ccccc1)C1CC2CC(C1)C2C(=...  generated
# 15  AABX    9  O=C(NC(Cc1ccccc1)C(=O)NC(Cc1ccccc1)C(=O)O)C1CC...  generated
# 13  AACC   10  O=C(NC(Cc1ccccc1)C(=O)NC(Cc1ccccc1)C(=O)O)C1CC...  generated
#
#      weight  score  weight_adj_score
# 0   786.926  -17.9        -18.718446
# 1   838.062  -17.7        -18.125294
# 2   838.062  -17.7        -18.125294
# 15  772.899  -17.2        -18.094489
# 13  772.899  -17.2        -18.094489

# %%
# Select top X ranked by similarity adjusted score for training data to refine the molecule generator RNN (ensures diverity)
training_smiles += list(weight_adjusted.head(5)['smile'])
len(training_smiles)
# Out:
# 31

# %%
import tensorflow
tensorflow.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From <ipython-input-27-cff5e14f5db6>:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
import numpy as np
from copy import copy

import keras

from lstm_chem.utils.config import process_config
from lstm_chem.model import LSTMChem
from lstm_chem.generator import LSTMChemGenerator
from lstm_chem.trainer import LSTMChemTrainer
from lstm_chem.data_loader import DataLoader
# Out:
# Using TensorFlow backend.

# %%
# Generate some with the base original model
CONFIG_FILE = 'experiments/2020-04-21/LSTM_Chem/config.json'
config = process_config(CONFIG_FILE)
modeler = LSTMChem(config, session='generate')
generator = LSTMChemGenerator(modeler)
# Out:
# Loading model architecture from experiments/2020-04-21/LSTM_Chem/model_arch.json ...
# Loading model checkpoint from experiments/2020-04-21/LSTM_Chem/checkpoints/LSTM_Chem-22-0.46.hdf5 ...
# Loaded the Model.

# %%
sample_number = 20

# %%
base_generated = generator.sample(num=sample_number)
# Out:
# 100%|██████████| 20/20 [00:14<00:00,  1.37it/s]

# %%
base_generated_mols = validate_mols(base_generated)
base_generated_smiles = convert_mols_to_smiles(base_generated_mols)
random.shuffle(base_generated_smiles)
random.shuffle(base_generated_smiles)
# Select X for training data to refine the molecule generator RNN (ensures diverity)
training_smiles += base_generated_smiles[0:5]
len(training_smiles)
# Out:
# 36

# %%
master_table = pd.read_csv('./generations/master_results_table_gen' + str(GLOBAL_GENERATION-1) + '.csv',sep=',')
master_table.head()
# Out:
#      id  gen                                              smile     source  \
# 0  AABL   10  O=C(NC(Cc1ccccc1)C(=O)NC(Cc1ccccc1)C(=O)O)C1CC...  generated
# 1  AADG    9  O=C(NC1CC2CCC(C1)N2CCc1ccccc1)C1CC2CC(C1)C2C(=...  generated
# 2  AACA   10  O=C(NC1CC2CCC(C1)N2CCc1ccccc1)C1CC2CC(C1)C2C(=...  generated
# 3  AABO    9  O=C(NC1CC2CCC(C1)N2CCc1ccccn1)C1CC2CCC(C1)C2C(...  generated
# 4  AABK   10  O=C(NC1CC2CCC(C1)N2CCc1ccccn1)C1CC2CCC(C1)C2C(...  generated
#
#     weight  score
# 0  786.926  -17.9
# 1  838.062  -17.7
# 2  838.062  -17.7
# 3  853.077  -17.6
# 4  853.077  -17.6

# %%
# Save the list of smiles to train on
with open('./generations/training/gen' + str(GLOBAL_GENERATION) + '_training.smi', 'w') as f:
    for item in training_smiles:
        f.write("%s\n" % item)

# %% [markdown]
# ## Retrain the network to create molecules more like those selected above

# %%
from lstm_chem.finetuner import LSTMChemFinetuner

# %%
config = process_config('experiments/2019-12-23/LSTM_Chem/config.json')
config['model_weight_filename'] = 'experiments/2019-12-23/LSTM_Chem/checkpoints/finetuned_gen' + str(GLOBAL_GENERATION-1) + '.hdf5'
config['finetune_data_filename'] = './generations/training/gen' + str(GLOBAL_GENERATION) + '_training.smi'
print(config)
# Out:
# batch_size: 512
# checkpoint_dir: experiments/2020-04-22/LSTM_Chem/checkpoints/
# checkpoint_mode: min
# checkpoint_monitor: val_loss
# checkpoint_save_best_only: false
# checkpoint_save_weights_only: true
# checkpoint_verbose: 1
# config_file: experiments/2019-12-23/LSTM_Chem/config.json
# data_filename: ./datasets/all_smiles_clean.smi
# data_length: 0
# exp_dir: experiments/2020-04-22/LSTM_Chem
# exp_name: LSTM_Chem
# finetune_batch_size: 1
# finetune_data_filename: ./generations/training/gen11_training.smi
# finetune_epochs: 5
# model_arch_filename: experiments/2019-12-23/LSTM_Chem/model_arch.json
# model_weight_filename: experiments/2019-12-23/LSTM_Chem/checkpoints/finetuned_gen10.hdf5
# num_epochs: 42
# optimizer: adam
# sampling_temp: 0.75
# seed: 71
# smiles_max_length: 128
# tensorboard_log_dir: experiments/2020-04-22/LSTM_Chem/logs/
# tensorboard_write_graph: true
# train_smi_max_len: 128
# units: 256
# validation_split: 0.1
# verbose_training: true

# %%
modeler = LSTMChem(config, session='finetune')
finetune_dl = DataLoader(config, data_type='finetune')

finetuner = LSTMChemFinetuner(modeler, finetune_dl)
finetuner.finetune()
# Out:
# Loading model architecture from experiments/2019-12-23/LSTM_Chem/model_arch.json ...
# 100%|██████████| 36/36 [00:00<00:00, 1723.53it/s]
# Loading model checkpoint from experiments/2019-12-23/LSTM_Chem/checkpoints/finetuned_gen10.hdf5 ...
# Loaded the Model.
# loading SMILES...
# done.
# tokenizing SMILES...
# done.
# WARNING:tensorflow:From /home/avinash/notebooks/deep_learning_coronavirus_cure/lstm_chem/finetuner.py:23: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 36 steps
# Epoch 1/5
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 29/36 [=======================>......] - ETA: 2s - loss: 0.3303WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 36/36 [==============================] - 14s 389ms/step - loss: 0.3579
# Epoch 2/5
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 29/36 [=======================>......] - ETA: 1s - loss: 0.2515WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 36/36 [==============================] - 10s 271ms/step - loss: 0.2536
# Epoch 3/5
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 29/36 [=======================>......] - ETA: 1s - loss: 0.2003WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 36/36 [==============================] - 10s 274ms/step - loss: 0.2073
# Epoch 4/5
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 29/36 [=======================>......] - ETA: 2s - loss: 0.1647WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 36/36 [==============================] - 10s 291ms/step - loss: 0.1619
# Epoch 5/5
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 29/36 [=======================>......] - ETA: 1s - loss: 0.1387WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 36/36 [==============================] - 10s 274ms/step - loss: 0.1422

# %%
finetuner.model.save_weights('experiments/2019-12-23/LSTM_Chem/checkpoints/finetuned_gen' + str(GLOBAL_GENERATION) + '.hdf5')

# %%
config['model_weight_filename'] = 'experiments/2019-12-23/LSTM_Chem/checkpoints/finetuned_gen' + str(GLOBAL_GENERATION) + '.hdf5'
modeler = LSTMChem(config, session='generate')
generator = LSTMChemGenerator(modeler)
print(config)
# Out:
# Loading model architecture from experiments/2019-12-23/LSTM_Chem/model_arch.json ...
# Loading model checkpoint from experiments/2019-12-23/LSTM_Chem/checkpoints/finetuned_gen11.hdf5 ...
# Loaded the Model.
# batch_size: 512
# checkpoint_dir: experiments/2020-04-22/LSTM_Chem/checkpoints/
# checkpoint_mode: min
# checkpoint_monitor: val_loss
# checkpoint_save_best_only: false
# checkpoint_save_weights_only: true
# checkpoint_verbose: 1
# config_file: experiments/2019-12-23/LSTM_Chem/config.json
# data_filename: ./datasets/all_smiles_clean.smi
# data_length: 0
# exp_dir: experiments/2020-04-22/LSTM_Chem
# exp_name: LSTM_Chem
# finetune_batch_size: 1
# finetune_data_filename: ./generations/training/gen11_training.smi
# finetune_epochs: 5
# model_arch_filename: experiments/2019-12-23/LSTM_Chem/model_arch.json
# model_weight_filename: experiments/2019-12-23/LSTM_Chem/checkpoints/finetuned_gen11.hdf5
# num_epochs: 42
# optimizer: adam
# sampling_temp: 0.75
# seed: 71
# smiles_max_length: 128
# tensorboard_log_dir: experiments/2020-04-22/LSTM_Chem/logs/
# tensorboard_write_graph: true
# train_smi_max_len: 128
# units: 256
# validation_split: 0.1
# verbose_training: true

# %%
sample_number = 5000
sampled_smiles = generator.sample(num=sample_number)
# Out:
# 100%|██████████| 5000/5000 [3:39:35<00:00,  2.64s/it]

# %%
valid_mols = []
for smi in sampled_smiles:
    mol = Chem.MolFromSmiles(smi)
    if mol is not None:
        valid_mols.append(mol)
# low validity
print('Validity: ', f'{len(valid_mols) / sample_number:.2%}')

valid_smiles = [Chem.MolToSmiles(mol) for mol in valid_mols]
# high uniqueness
print('Uniqueness: ', f'{len(set(valid_smiles)) / len(valid_smiles):.2%}')

# Of valid smiles generated, how many are truly original vs ocurring in the training data
import pandas as pd
training_data = pd.read_csv('./datasets/all_smiles_clean.smi', header=None)
training_set = set(list(training_data[0]))
original = []
for smile in list(set(valid_smiles)):
    if not smile in training_set:
        original.append(smile)
print('Originality: ', f'{len(set(original)) / len(set(valid_smiles)):.2%}')
# Out:
# Validity:  89.26%
# Uniqueness:  16.40%
# Originality:  99.45%

# %%
valid_smiles = list(set(valid_smiles))
len(valid_smiles)
# Out:
# 732

# %%
#take the valid smiles from above and run them through process to add to tracking table and to generate next PyRx testing data
mols_for_next_generation = validate_mols(valid_smiles)

master_table = pd.read_csv('./generations/master_results_table_gen' + str(GLOBAL_GENERATION-1) +'.csv',sep=',')
new_mols_to_test = append_to_tracking_table(master_table,mols_for_next_generation, 'generated', GLOBAL_GENERATION)
mols_for_pd = new_mols_to_test[0]
mols_for_export = new_mols_to_test[1]

master_table = master_table.append(mols_for_pd)
master_table = master_table.reset_index(drop=True)
master_table.to_csv(r'./generations/master_results_table_gen' + str(GLOBAL_GENERATION) + '.csv', index=False)
# Out:
# idAAAAgen11
# idAAABgen11
# idAAACgen11
# idAAADgen11
# idAAAEgen11
# idAAAFgen11
# idAAAGgen11
# idAAAHgen11
# idAAAIgen11
# idAAAJgen11
# idAAAKgen11
# idAAALgen11
# idAAAMgen11
# idAAANgen11
# idAAAOgen11
# idAAAPgen11
# idAAAQgen11
# idAAARgen11
# idAAASgen11
# idAAATgen11
# idAAAUgen11
# idAAAVgen11
# idAAAWgen11
# idAAAXgen11
# idAAAYgen11
# idAAAZgen11
# idAABAgen11
# idAABBgen11
# idAABCgen11
# idAABDgen11
# idAABEgen11
# idAABFgen11
# idAABGgen11
# idAABHgen11
# idAABIgen11
# idAABJgen11
# idAABKgen11
# idAABLgen11
# idAABMgen11
# idAABNgen11
# idAABOgen11
# idAABPgen11
# idAABQgen11
# idAABRgen11
# idAABSgen11
# idAABTgen11
# idAABUgen11
# idAABVgen11
# idAABWgen11
# idAABXgen11
# idAABYgen11
# idAABZgen11
# idAACAgen11
# idAACBgen11
# idAACCgen11
# idAACDgen11
# idAACEgen11
# idAACFgen11
# idAACGgen11
# idAACHgen11
# idAACIgen11
# idAACJgen11
# idAACKgen11
# idAACLgen11
# idAACMgen11
# idAACNgen11
# idAACOgen11
# idAACPgen11
# idAACQgen11
# idAACRgen11
# idAACSgen11
# idAACTgen11
# idAACUgen11
# idAACVgen11
# idAACWgen11
# idAACXgen11
# idAACYgen11
# idAACZgen11
# idAADAgen11
# idAADBgen11
# idAADCgen11
# idAADDgen11
# idAADEgen11
# idAADFgen11
# idAADGgen11
# idAADHgen11
# idAADIgen11
# idAADJgen11
# idAADKgen11
# idAADLgen11
# idAADMgen11
# idAADNgen11
# idAADOgen11
# idAADPgen11
# idAADQgen11
# idAADRgen11
# idAADSgen11
# idAADTgen11
# idAADUgen11
# idAADVgen11
# idAADWgen11
# idAADXgen11
# idAADYgen11
# idAADZgen11
# idAAEAgen11
# idAAEBgen11
# idAAECgen11
# idAAEDgen11
# idAAEEgen11
# idAAEFgen11
# idAAEGgen11
# idAAEHgen11
# idAAEIgen11
# idAAEJgen11
# idAAEKgen11
# idAAELgen11
# idAAEMgen11
# idAAENgen11
# idAAEOgen11
# idAAEPgen11
# idAAEQgen11
# idAAERgen11
# idAAESgen11
# idAAETgen11
# idAAEUgen11
# idAAEVgen11
# idAAEWgen11
# idAAEXgen11
# idAAEYgen11
# idAAEZgen11
# idAAFAgen11
# idAAFBgen11
# idAAFCgen11
# idAAFDgen11
# idAAFEgen11
# idAAFFgen11
# idAAFGgen11
# idAAFHgen11
# idAAFIgen11
# idAAFJgen11
# idAAFKgen11
# idAAFLgen11
# idAAFMgen11
# idAAFNgen11
# idAAFOgen11
# idAAFPgen11
# idAAFQgen11
# idAAFRgen11
# idAAFSgen11
# idAAFTgen11
# idAAFUgen11
# idAAFVgen11
# idAAFWgen11
# idAAFXgen11
# idAAFYgen11
# idAAFZgen11
# idAAGAgen11
# idAAGBgen11
# idAAGCgen11
# idAAGDgen11
# idAAGEgen11
# idAAGFgen11
# idAAGGgen11
# idAAGHgen11
# idAAGIgen11
# idAAGJgen11
# idAAGKgen11
# idAAGLgen11
# idAAGMgen11
# idAAGNgen11
# idAAGOgen11
# idAAGPgen11
# idAAGQgen11
# idAAGRgen11
# idAAGSgen11
# idAAGTgen11
# idAAGUgen11
# idAAGVgen11
# idAAGWgen11
# idAAGXgen11
# idAAGYgen11
# idAAGZgen11
# idAAHAgen11
# idAAHBgen11
# idAAHCgen11
# idAAHDgen11
# idAAHEgen11
# idAAHFgen11
# idAAHGgen11
# idAAHHgen11
# idAAHIgen11
# idAAHJgen11
# idAAHKgen11
# idAAHLgen11
# idAAHMgen11
# idAAHNgen11
# idAAHOgen11
# idAAHPgen11
# idAAHQgen11
# idAAHRgen11
# idAAHSgen11
# idAAHTgen11
# idAAHUgen11
# idAAHVgen11
# idAAHWgen11
# idAAHXgen11
# idAAHYgen11
# idAAHZgen11
# idAAIAgen11
# idAAIBgen11
# idAAICgen11
# idAAIDgen11
# idAAIEgen11
# idAAIFgen11
# idAAIGgen11
# idAAIHgen11
# idAAIIgen11
# idAAIJgen11
# idAAIKgen11
# idAAILgen11
# idAAIMgen11
# idAAINgen11
# idAAIOgen11
# idAAIPgen11
# idAAIQgen11
# idAAIRgen11
# idAAISgen11
# idAAITgen11
# idAAIUgen11
# idAAIVgen11
# idAAIWgen11
# idAAIXgen11
# idAAIYgen11
# idAAIZgen11
# idAAJAgen11
# idAAJBgen11
# idAAJCgen11
# idAAJDgen11
# idAAJEgen11
# idAAJFgen11
# idAAJGgen11
# idAAJHgen11
# idAAJIgen11
# idAAJJgen11
# idAAJKgen11
# idAAJLgen11
# idAAJMgen11
# idAAJNgen11
# idAAJOgen11
# idAAJPgen11
# idAAJQgen11
# idAAJRgen11
# idAAJSgen11
# idAAJTgen11
# idAAJUgen11
# idAAJVgen11
# idAAJWgen11
# idAAJXgen11
# idAAJYgen11
# idAAJZgen11
# idAAKAgen11
# idAAKBgen11
# idAAKCgen11
# idAAKDgen11
# idAAKEgen11
# idAAKFgen11
# idAAKGgen11
# idAAKHgen11
# idAAKIgen11
# idAAKJgen11
# idAAKKgen11
# idAAKLgen11
# idAAKMgen11
# idAAKNgen11
# idAAKOgen11
# idAAKPgen11
# idAAKQgen11
# idAAKRgen11
# idAAKSgen11
# idAAKTgen11
# idAAKUgen11
# idAAKVgen11
# idAAKWgen11
# idAAKXgen11
# idAAKYgen11
# idAAKZgen11
# idAALAgen11
# idAALBgen11
# idAALCgen11
# idAALDgen11
# idAALEgen11
# idAALFgen11
# idAALGgen11
# idAALHgen11
# idAALIgen11
# idAALJgen11
# idAALKgen11
# idAALLgen11
# idAALMgen11
# idAALNgen11
# idAALOgen11
# idAALPgen11
# idAALQgen11
# idAALRgen11
# idAALSgen11
# idAALTgen11
# idAALUgen11
# idAALVgen11
# idAALWgen11
# idAALXgen11
# idAALYgen11
# idAALZgen11
# idAAMAgen11
# idAAMBgen11
# idAAMCgen11
# idAAMDgen11
# idAAMEgen11
# idAAMFgen11
# idAAMGgen11
# idAAMHgen11
# idAAMIgen11
# idAAMJgen11
# idAAMKgen11
# idAAMLgen11
# idAAMMgen11
# idAAMNgen11
# idAAMOgen11
# idAAMPgen11
# idAAMQgen11
# idAAMRgen11
# idAAMSgen11
# idAAMTgen11
# idAAMUgen11
# idAAMVgen11
# idAAMWgen11
# idAAMXgen11
# idAAMYgen11
# idAAMZgen11
# idAANAgen11
# idAANBgen11
# idAANCgen11
# idAANDgen11
# idAANEgen11
# idAANFgen11
# idAANGgen11
# idAANHgen11
# idAANIgen11
# idAANJgen11
# idAANKgen11
# idAANLgen11
# idAANMgen11
# idAANNgen11
# idAANOgen11
# idAANPgen11
# idAANQgen11
# idAANRgen11
# idAANSgen11
# idAANTgen11
# idAANUgen11
# idAANVgen11
# idAANWgen11
# idAANXgen11
# idAANYgen11
# idAANZgen11
# idAAOAgen11
# idAAOBgen11
# idAAOCgen11
# idAAODgen11
# idAAOEgen11
# idAAOFgen11
# idAAOGgen11
# idAAOHgen11
# idAAOIgen11
# idAAOJgen11
# idAAOKgen11
# idAAOLgen11
# idAAOMgen11
# idAAONgen11
# idAAOOgen11
# idAAOPgen11
# idAAOQgen11
# idAAORgen11
# idAAOSgen11
# idAAOTgen11
# idAAOUgen11
# idAAOVgen11
# idAAOWgen11
# idAAOXgen11
# idAAOYgen11
# idAAOZgen11
# idAAPAgen11
# idAAPBgen11
# idAAPCgen11
# idAAPDgen11
# idAAPEgen11
# idAAPFgen11
# idAAPGgen11
# idAAPHgen11
# idAAPIgen11
# idAAPJgen11
# idAAPKgen11
# idAAPLgen11
# idAAPMgen11
# idAAPNgen11
# idAAPOgen11
# idAAPPgen11
# idAAPQgen11
# idAAPRgen11
# idAAPSgen11
# idAAPTgen11
# idAAPUgen11
# idAAPVgen11
# idAAPWgen11
# idAAPXgen11
# idAAPYgen11
# idAAPZgen11
# idAAQAgen11
# idAAQBgen11
# idAAQCgen11
# idAAQDgen11
# idAAQEgen11
# idAAQFgen11
# idAAQGgen11
# idAAQHgen11
# idAAQIgen11
# idAAQJgen11
# idAAQKgen11
# idAAQLgen11
# idAAQMgen11
# idAAQNgen11
# idAAQOgen11
# idAAQPgen11
# idAAQQgen11
# idAAQRgen11
# idAAQSgen11
# idAAQTgen11
# idAAQUgen11
# idAAQVgen11
# idAAQWgen11
# idAAQXgen11
# idAAQYgen11
# idAAQZgen11
# idAARAgen11
# idAARBgen11
# idAARCgen11
# idAARDgen11
# idAAREgen11
# idAARFgen11
# idAARGgen11
# idAARHgen11
# idAARIgen11
# idAARJgen11
# idAARKgen11
# idAARLgen11
# idAARMgen11
# idAARNgen11
# idAAROgen11
# idAARPgen11
# idAARQgen11
# idAARRgen11
# idAARSgen11
# idAARTgen11
# idAARUgen11
# idAARVgen11
# idAARWgen11
# idAARXgen11
# idAARYgen11
# idAARZgen11
# idAASAgen11
# idAASBgen11
# idAASCgen11
# idAASDgen11
# idAASEgen11
# idAASFgen11
# idAASGgen11
# idAASHgen11
# idAASIgen11
# idAASJgen11
# idAASKgen11
# idAASLgen11
# idAASMgen11
# idAASNgen11
# idAASOgen11
# idAASPgen11
# idAASQgen11
# idAASRgen11
# idAASSgen11
# idAASTgen11
# idAASUgen11
# idAASVgen11
# idAASWgen11
# idAASXgen11
# idAASYgen11
# idAASZgen11
# idAATAgen11
# idAATBgen11
# idAATCgen11
# idAATDgen11
# idAATEgen11
# idAATFgen11
# idAATGgen11
# idAATHgen11
# idAATIgen11
# idAATJgen11
# idAATKgen11
# idAATLgen11
# idAATMgen11
# idAATNgen11
# idAATOgen11
# idAATPgen11
# idAATQgen11
# idAATRgen11
# idAATSgen11
# idAATTgen11
# idAATUgen11
# idAATVgen11
# idAATWgen11
# idAATXgen11
# idAATYgen11
# idAATZgen11
# idAAUAgen11
# idAAUBgen11
# idAAUCgen11
# idAAUDgen11
# idAAUEgen11
# idAAUFgen11
# idAAUGgen11
# idAAUHgen11
# idAAUIgen11
# idAAUJgen11
# idAAUKgen11
# idAAULgen11
# idAAUMgen11
# idAAUNgen11
# idAAUOgen11
# idAAUPgen11
# idAAUQgen11
# idAAURgen11
# idAAUSgen11
# idAAUTgen11
# idAAUUgen11
# idAAUVgen11
# idAAUWgen11
# idAAUXgen11
# idAAUYgen11
# idAAUZgen11
# idAAVAgen11
# idAAVBgen11
# idAAVCgen11
# idAAVDgen11
# idAAVEgen11
# idAAVFgen11
# idAAVGgen11
# idAAVHgen11
# idAAVIgen11
# idAAVJgen11
# idAAVKgen11
# idAAVLgen11
# idAAVMgen11
# idAAVNgen11
# idAAVOgen11
# idAAVPgen11
# idAAVQgen11
# idAAVRgen11
# idAAVSgen11
# idAAVTgen11
# idAAVUgen11
# idAAVVgen11
# idAAVWgen11
# idAAVXgen11
# idAAVYgen11
# idAAVZgen11
# idAAWAgen11
# idAAWBgen11
# idAAWCgen11
# idAAWDgen11
# idAAWEgen11
# idAAWFgen11
# idAAWGgen11
# idAAWHgen11
# idAAWIgen11
# idAAWJgen11
# idAAWKgen11
# idAAWLgen11
# idAAWMgen11
# idAAWNgen11
# idAAWOgen11
# idAAWPgen11
# idAAWQgen11
# idAAWRgen11
# idAAWSgen11
# idAAWTgen11
# idAAWUgen11
# idAAWVgen11
# idAAWWgen11
# idAAWXgen11
# idAAWYgen11
# idAAWZgen11
# idAAXAgen11
# idAAXBgen11
# idAAXCgen11
# idAAXDgen11
# idAAXEgen11
# idAAXFgen11
# idAAXGgen11
# idAAXHgen11
# idAAXIgen11
# idAAXJgen11
# idAAXKgen11
# idAAXLgen11
# idAAXMgen11
# idAAXNgen11
# idAAXOgen11
# idAAXPgen11
# idAAXQgen11
# idAAXRgen11
# idAAXSgen11
# idAAXTgen11
# idAAXUgen11
# idAAXVgen11
# idAAXWgen11
# idAAXXgen11
# idAAXYgen11
# idAAXZgen11
# idAAYAgen11
# idAAYBgen11
# idAAYCgen11
# idAAYDgen11
# idAAYEgen11
# idAAYFgen11
# idAAYGgen11
# idAAYHgen11
# idAAYIgen11
# idAAYJgen11
# idAAYKgen11
# idAAYLgen11
# idAAYMgen11
# idAAYNgen11
# idAAYOgen11
# idAAYPgen11
# idAAYQgen11
# idAAYRgen11
# idAAYSgen11
# idAAYTgen11
# idAAYUgen11
# idAAYVgen11
# idAAYWgen11
# idAAYXgen11
# idAAYYgen11
# idAAYZgen11
# idAAZAgen11
# idAAZBgen11
# idAAZCgen11
# idAAZDgen11
# idAAZEgen11
# idAAZFgen11
# idAAZGgen11
# idAAZHgen11
# idAAZIgen11
# idAAZJgen11
# idAAZKgen11
# idAAZLgen11
# idAAZMgen11
# idAAZNgen11
# idAAZOgen11
# idAAZPgen11
# idAAZQgen11
# idAAZRgen11
# idAAZSgen11
# idAAZTgen11
# idAAZUgen11
# idAAZVgen11
# idAAZWgen11
# idAAZXgen11
# idAAZYgen11
# idAAZZgen11
# idABAAgen11
# idABABgen11
# idABACgen11
# idABADgen11
# idABAEgen11
# idABAFgen11
# idABAGgen11
# idABAHgen11
# idABAIgen11
# idABAJgen11
# idABAKgen11
# idABALgen11
# idABAMgen11
# idABANgen11
# idABAOgen11
# idABAPgen11
# idABAQgen11
# idABARgen11
# idABASgen11
# idABATgen11
# idABAUgen11
# idABAVgen11
# idABAWgen11
# idABAXgen11
# idABAYgen11
# idABAZgen11
# idABBAgen11
# idABBBgen11
# idABBCgen11
# idABBDgen11
# idABBEgen11
# idABBFgen11
# idABBGgen11
# idABBHgen11
# idABBIgen11
# idABBJgen11
# idABBKgen11
# idABBLgen11
# idABBMgen11
# idABBNgen11
# idABBOgen11
# idABBPgen11
# idABBQgen11
# idABBRgen11
# idABBSgen11
# idABBTgen11
# idABBUgen11
# idABBVgen11
# idABBWgen11
# idABBXgen11
# idABBYgen11
# idABBZgen11
# idABCAgen11
# idABCBgen11
# idABCCgen11
# idABCDgen11

# %%
len(mols_for_export)
# Out:
# 732

# %%
write_gen_to_sdf(mols_for_export, GLOBAL_GENERATION, 2000)
print('ok')
# Out:
# ok
