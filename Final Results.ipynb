# %% [markdown]
# # Description
#
# This notebook is used to tabulate final results and compare novel generated molecules vs HIV inhibitors vs Remdesivir which entered clinical trials just a few days ago.

# %% [markdown]
# ## Now the best results and save to sdf for last double check tabulation in PyRx

# %%
import pandas as pd
from rdkit import Chem, DataStructs
import random
import numpy as np
import rdkit.Chem.PropertyMol

# %%
final = pd.read_csv('./generations/master_results_table_gen10.csv',sep=',')
final = final.sort_values('score', ascending=True)
print(final.shape)
final.head()
# Out:
# (3020, 6)
#      id  gen                                              smile     source  \
# 0  AABL   10  O=C(NC(Cc1ccccc1)C(=O)NC(Cc1ccccc1)C(=O)O)C1CC...  generated
# 1  AADG    9  O=C(NC1CC2CCC(C1)N2CCc1ccccc1)C1CC2CC(C1)C2C(=...  generated
# 2  AACA   10  O=C(NC1CC2CCC(C1)N2CCc1ccccc1)C1CC2CC(C1)C2C(=...  generated
# 3  AABO    9  O=C(NC1CC2CCC(C1)N2CCc1ccccn1)C1CC2CCC(C1)C2C(...  generated
# 4  AABK   10  O=C(NC1CC2CCC(C1)N2CCc1ccccn1)C1CC2CCC(C1)C2C(...  generated
#
#     weight  score
# 0  786.926  -17.9
# 1  838.062  -17.7
# 2  838.062  -17.7
# 3  853.077  -17.6
# 4  853.077  -17.6

# %%
final_max = final.groupby("smile").max()[["score","gen"]].reset_index()
final_max = final_max.sort_values('score', ascending=True)
print(final_max.shape)
final_max.head()
# Out:
# (2728, 3)
#                                                   smile  score  gen
# 2437  O=C(NC(Cc1ccccc1)C(=O)NC(Cc1ccccc1)C(=O)O)C1CC...  -17.9   10
# 2474  O=C(NC1CC2CCC(C1)N2CCc1ccccc1)C1CC2CC(C1)C2C(=...  -17.7   10
# 2492  O=C(NC1CC2CCCC(C1)N2CCc1ccccn1)C1CC2CCC(C1)C2C...  -17.6   10
# 2482  O=C(NC1CC2CCC(C1)N2CCc1ccccn1)C1CC2CCC(C1)C2C(...  -17.6   10
# 2480  O=C(NC1CC2CCC(C1)N2CCc1ccccn1)C1CC2CC(C1)C2C(=...  -17.5   10

# %%
final_joined = pd.merge(final_max, final, on=['smile','gen'], suffixes=('_old','_new'), how='left')
final_joined = final_joined[(final_joined['score_new'] <= -15.0) & (final_joined['weight'] < 900)]
final_joined['score'] = final_joined['score_new']
final_joined = final_joined.drop('score_old', axis=1)
final_joined = final_joined.drop('score_new', axis=1)
print(final_joined.shape)
final_joined.head()
# Out:
# (41, 6)
#                                                smile  gen    id     source  \
# 0  O=C(NC(Cc1ccccc1)C(=O)NC(Cc1ccccc1)C(=O)O)C1CC...   10  AABL  generated
# 1  O=C(NC1CC2CCC(C1)N2CCc1ccccc1)C1CC2CC(C1)C2C(=...   10  AACA  generated
# 2  O=C(NC1CC2CCCC(C1)N2CCc1ccccn1)C1CC2CCC(C1)C2C...   10  AABP  generated
# 3  O=C(NC1CC2CCC(C1)N2CCc1ccccn1)C1CC2CCC(C1)C2C(...   10  AABK  generated
# 4  O=C(NC1CC2CCC(C1)N2CCc1ccccn1)C1CC2CC(C1)C2C(=...   10  AAAF  generated
#
#     weight  score
# 0  786.926  -17.9
# 1  838.062  -17.7
# 2  867.104  -17.6
# 3  853.077  -17.6
# 4  839.050  -17.5

# %%
hiv = final[final['source'] == 'hiv']
hiv.head()
# Out:
#         id  gen                                              smile source  \
# 548   ABSI    0  CC(C)(C)NC(=O)C1CC2CCCCC2CN1CC(O)C(Cc1ccccc1)N...    hiv
# 713   ABSH    0  CC(C)CN(CC(O)C(Cc1ccccc1)NC(=O)OC1COC2OCCC12)S...    hiv
# 832   ABSN    0  COC(=O)NC(C(=O)NC(Cc1ccccc1)C(O)CN(Cc1ccc(-c2c...    hiv
# 892   ABSK    0  CC(C)CN(CC(O)C(Cc1ccccc1)NC(=O)OC1COC2OCCC12)S...    hiv
# 1001  ABSL    0  Cc1c(O)cccc1C(=O)NC(CSc1ccccc1)C(O)CN1CC2CCCCC...    hiv
#
#        weight  score
# 548   670.855  -10.8
# 713   756.004  -10.0
# 832   704.869   -9.5
# 892   547.674   -9.2
# 1001  567.796   -8.5

# %%
final_table = final_joined.append(hiv)
final_table.head()
# Out:
#                                                smile  gen    id     source  \
# 0  O=C(NC(Cc1ccccc1)C(=O)NC(Cc1ccccc1)C(=O)O)C1CC...   10  AABL  generated
# 1  O=C(NC1CC2CCC(C1)N2CCc1ccccc1)C1CC2CC(C1)C2C(=...   10  AACA  generated
# 2  O=C(NC1CC2CCCC(C1)N2CCc1ccccn1)C1CC2CCC(C1)C2C...   10  AABP  generated
# 3  O=C(NC1CC2CCC(C1)N2CCc1ccccn1)C1CC2CCC(C1)C2C(...   10  AABK  generated
# 4  O=C(NC1CC2CCC(C1)N2CCc1ccccn1)C1CC2CC(C1)C2C(=...   10  AAAF  generated
#
#     weight  score
# 0  786.926  -17.9
# 1  838.062  -17.7
# 2  867.104  -17.6
# 3  853.077  -17.6
# 4  839.050  -17.5

# %%
# Note I also manually added Remdesivir because as working on this it went into clinical trials
# https://en.wikipedia.org/wiki/Remdesivir
final_table.to_csv(r'./generations/master_results_table_final2.csv', index=False)

# %%
final_table = pd.read_csv('./generations/master_results_table_final.csv')
final_table.tail()
# Out:
#                                                 smile  gen    id source  \
# 50  CC(C)CN(CC(O)C(Cc1ccccc1)NC(=O)OC1CCOC1)S(=O)(...    0  ABSM    hiv
# 51  CCCC1(CCc2ccccc2)CC(O)=C(C(CC)c2cccc(NS(=O)(=O...    0  ABSP    hiv
# 52           O=C1Nc2ccc(Cl)cc2C(C#CC2CC2)(C(F)(F)F)O1    0  ABSQ    hiv
# 53  CC(C)c1nc(CN(C)C(=O)NC(C(=O)NC(Cc2ccccc2)CC(O)...    0  ABSO    hiv
# 54  Cc1cccc(C)c1OCC(=O)NC(Cc1ccccc1)C(O)CC(Cc1cccc...    0  ABSJ    hiv
#
#      weight  score_best  score_avg  similarity_to_hiv_inhibitors  \
# 50  505.637        -7.7  -7.288889                      0.558467
# 51  602.675        -7.6  -7.200000                      0.493003
# 52  315.678        -6.4  -6.055556                      0.433602
# 53  720.962         NaN        NaN                      0.451159
# 54  628.814         NaN        NaN                      0.430199
#
#     similarity_to_remdesivir
# 50                  0.404068
# 51                  0.562334
# 52                  0.481928
# 53                  0.476061
# 54                  0.422064

# %%
def set_molecule(row):
    mol = Chem.MolFromSmiles(row['smile'])
    pm = Chem.PropertyMol.PropertyMol(mol)
    title = 'id' + str(row['id']) + 'gen'+ str(row['gen'])
#     print(title)
    # Enables for tracking which molecule is which in PyRx GUI and PyRx results export
    pm.SetProp('Title', title)
    return pm

# %%
mols_for_export = final_table.apply(set_molecule, axis=1)
# list(mols_for_export)

# %%
w = Chem.SDWriter('./generations/genfinal.sdf')
for m in mols_for_export:
    w.write(m)

# %% [markdown]
# ## Rerun everything through PyRx once more to double check, then publish final metrics

# %%
new_scores = pd.read_csv('./generations/results/results_genfinal.csv',sep=',')
new_scores.head()
# Out:
#              Ligand  Binding Affinity  rmsd/ub   rmsd/lb
# 0  6lu7_idAABLgen10             -17.9    0.000     0.000
# 1  6lu7_idAACAgen10             -17.7    0.000     0.000
# 2  6lu7_idAABPgen10             -17.6    0.000     0.000
# 3  6lu7_idAABKgen10             -17.6    0.000     0.000
# 4  6lu7_idAACAgen10             -17.5    7.073     2.871

# %%
new_scores = new_scores.groupby("Ligand").agg({'Binding Affinity': [np.min,np.average]}).reset_index()
new_scores.head()
# Out:
#              Ligand Binding Affinity
#                                 amin    average
# 0  6lu7_idAAAAgen11            -13.5 -12.666667
# 1  6lu7_idAAACgen10            -16.3 -14.511111
# 2  6lu7_idAAAFgen10            -17.5 -15.677778
# 3  6lu7_idAAAGgen10            -16.2 -14.311111
# 4  6lu7_idAAAHgen10            -16.3 -14.357143

# %%
new_scores['id'] = new_scores['Ligand'].str.split("_").str[1].str.split("gen").str[0].str.split("id").str[1]
new_scores['gen'] = new_scores['Ligand'].str.split("_").str[1].str.split("gen").str[1]
new_scores['score_best'] = new_scores["Binding Affinity"]["amin"]
new_scores['score_avg'] = new_scores["Binding Affinity"]["average"]
new_scores = new_scores[['id','gen','score_best','score_avg']]
new_scores.head()
# Out:
#      id gen score_best  score_avg
#
# 0  AAAA  11      -13.5 -12.666667
# 1  AAAC  10      -16.3 -14.511111
# 2  AAAF  10      -17.5 -15.677778
# 3  AAAG  10      -16.2 -14.311111
# 4  AAAH  10      -16.3 -14.357143

# %%
new_scores.id = new_scores.id.astype(str)
new_scores.gen = new_scores.gen.astype(str)
final_table.id = final_table.id.astype(str)
final_table.gen = final_table.gen.astype(str)

# %%
new_table = pd.merge(final_table, new_scores, on=['id','gen'], suffixes=('_old','_new'), how='left')
new_table['score_best'] = new_table[('score_best', '')]
new_table['score_avg'] = new_table[('score_avg', '')]
new_table = new_table.drop([('score_best', ''),('score_avg', '')], axis=1)
new_table = new_table.sort_values('score_best', ascending=True)
new_table.tail()
# Out:
# /anaconda/envs/novodrug/lib/python3.7/site-packages/pandas/core/reshape/merge.py:618: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
#                                                 smile gen    id source  \
# 50  CC(C)CN(CC(O)C(Cc1ccccc1)NC(=O)OC1CCOC1)S(=O)(...   0  ABSM    hiv
# 51  CCCC1(CCc2ccccc2)CC(O)=C(C(CC)c2cccc(NS(=O)(=O...   0  ABSP    hiv
# 52           O=C1Nc2ccc(Cl)cc2C(C#CC2CC2)(C(F)(F)F)O1   0  ABSQ    hiv
# 53  CC(C)c1nc(CN(C)C(=O)NC(C(=O)NC(Cc2ccccc2)CC(O)...   0  ABSO    hiv
# 54  Cc1cccc(C)c1OCC(=O)NC(Cc1ccccc1)C(O)CC(Cc1cccc...   0  ABSJ    hiv
#
#      weight  score_best  score_avg  similarity_to_hiv_inhibitors  \
# 50  505.637        -7.7  -7.288889                      0.558467
# 51  602.675        -7.6  -7.200000                      0.493003
# 52  315.678        -6.4  -6.055556                      0.433602
# 53  720.962         NaN        NaN                      0.451159
# 54  628.814         NaN        NaN                      0.430199
#
#     similarity_to_remdesivir
# 50                  0.404068
# 51                  0.562334
# 52                  0.481928
# 53                  0.476061
# 54                  0.422064

# %%
new_table.columns
# Out:
# Index(['smile', 'gen', 'id', 'source', 'weight', 'score_best', 'score_avg',
#        'similarity_to_hiv_inhibitors', 'similarity_to_remdesivir'],
#       dtype='object')

# %%
hiv_smiles = new_table[(new_table['source'] == 'hiv') & (new_table['score_best'].notnull())]
hiv_smiles_list = list(hiv_smiles['smile'])
hiv_smiles.head(20)
# Out:
#                                                 smile gen    id source  \
# 42  CC(C)(C)NC(=O)C1CC2CCCCC2CN1CC(O)C(Cc1ccccc1)N...   0  ABSI    hiv
# 43  CC(C)CN(CC(O)C(Cc1ccccc1)NC(=O)OC1COC2OCCC12)S...   0  ABSH    hiv
# 44  CC(C)CN(CC(O)C(Cc1ccccc1)NC(=O)OC1COC2OCCC12)S...   0  ABSK    hiv
# 45  COC(=O)NC(C(=O)NC(Cc1ccccc1)C(O)CN(Cc1ccc(-c2c...   0  ABSN    hiv
# 46  CC(C)(C)NC(=O)C1CN(Cc2cccnc2)CCN1CC(O)CC(Cc1cc...   0  ABSR    hiv
# 47  Cc1c(O)cccc1C(=O)NC(CSc1ccccc1)C(O)CN1CC2CCCCC...   0  ABSL    hiv
# 48  CCOP(=O)(COc1ccc(CC(NC(=O)OC2COC3OCCC23)C(O)CN...   0  ABSS    hiv
# 49  COC(=O)NC(C(=O)NCCCCC(CO)N(CC(C)C)S(=O)(=O)c1c...   0  ABST    hiv
# 50  CC(C)CN(CC(O)C(Cc1ccccc1)NC(=O)OC1CCOC1)S(=O)(...   0  ABSM    hiv
# 51  CCCC1(CCc2ccccc2)CC(O)=C(C(CC)c2cccc(NS(=O)(=O...   0  ABSP    hiv
# 52           O=C1Nc2ccc(Cl)cc2C(C#CC2CC2)(C(F)(F)F)O1   0  ABSQ    hiv
#
#      weight  score_best  score_avg  similarity_to_hiv_inhibitors  \
# 42  670.855       -10.7  -9.633333                      0.513706
# 43  756.004        -9.9  -9.355556                      0.588024
# 44  547.674        -9.7  -8.655556                      0.592052
# 45  704.869        -9.1  -8.366667                      0.501215
# 46  613.803        -8.5  -8.133333                      0.474714
# 47  567.796        -8.1  -7.833333                      0.472333
# 48  728.798        -8.1  -7.733333                      0.585561
# 49  624.804        -7.9  -7.677778                      0.511851
# 50  505.637        -7.7  -7.288889                      0.558467
# 51  602.675        -7.6  -7.200000                      0.493003
# 52  315.678        -6.4  -6.055556                      0.433602
#
#     similarity_to_remdesivir
# 42                  0.489396
# 43                  0.589407
# 44                  0.470364
# 45                  0.453570
# 46                  0.473684
# 47                  0.432787
# 48                  0.530075
# 49                  0.433820
# 50                  0.404068
# 51                  0.562334
# 52                  0.481928

# %%
hiv_fingerprints = []
for smile in hiv_smiles_list:
    hiv_fingerprints.append(Chem.RDKFingerprint(Chem.MolFromSmiles(smile)))

def calc_hiv_similarity_score(row):
    fingerprint = Chem.RDKFingerprint(Chem.MolFromSmiles(row['smile']))
    similarity = np.mean(DataStructs.BulkTanimotoSimilarity(fingerprint,hiv_fingerprints))
    return similarity

remdesivir_fingerprint = Chem.RDKFingerprint(Chem.MolFromSmiles('CCC(CC)COC(=O)[C@H](C)NP(=O)(OC[C@H]1O[C@](C#N)([C@H](O)[C@@H]1O)C1=CC=C2N1N=CN=C2N)OC1=CC=CC=C1'))

new_table['similarity_to_hiv_inhibitors'] = new_table.apply(calc_hiv_similarity_score, axis=1)
new_table['similarity_to_remdesivir'] = new_table['smile'].apply(lambda x: DataStructs.TanimotoSimilarity(Chem.RDKFingerprint(Chem.MolFromSmiles(x)),remdesivir_fingerprint))
new_table.head(50)
# Out:
#                                                 smile gen    id      source  \
# 0   O=C(NC(Cc1ccccc1)C(=O)NC(Cc1ccccc1)C(=O)O)C1CC...  10  AABL   generated
# 1   O=C(NC1CC2CCC(C1)N2CCc1ccccc1)C1CC2CC(C1)C2C(=...  10  AACA   generated
# 2   O=C(NC1CC2CCCC(C1)N2CCc1ccccn1)C1CC2CCC(C1)C2C...  10  AABP   generated
# 3   O=C(NC1CC2CCC(C1)N2CCc1ccccn1)C1CC2CCC(C1)C2C(...  10  AABK   generated
# 4   O=C(NC1CC2CCC(C1)N2CCc1ccccn1)C1CC2CC(C1)C2C(=...  10  AAAF   generated
# 5   O=C(NC1CC2CCCC(C1)N2CCc1ccccc1)C1CC2CCC(C1)C2C...  10  AAAJ   generated
# 6   O=C(NC1CC2CCCC(C1)N2CCc1ccccc1)C1CC2CC(C1)C2C(...  10  AAAN   generated
# 7   O=C(NC1CC2CCCC(C1)N2CCc1ccccc1)C1COC2CC(C1)C2C...  10  AABF   generated
# 8   O=C(NC1CC2CCC(C1)N2CCc1ccccc1)C1CC2CCC(C1)C2C(...  10  AAAU   generated
# 9   O=C(NC(Cc1ccccc1)C(=O)NC(Cc1ccccc1)C(=O)O)C1CC...  10  AACC   generated
# 10  O=C(NC1CC2CC(C1)N2CCc1ccccn1)C1CC2CC(C1)C2C(=O...  10  AABB   generated
# 12  O=C(O)C(Cc1ccccc1)NC(=O)C(Cc1ccccc1)NC(=O)C1C2...  10  AABQ   generated
# 11  NC(=O)C(Cc1ccccc1)NC(=O)C(Cc1ccccc1)NC(=O)C1C2...  10  AABX   generated
# 13  O=C(O)C(Cc1ccccc1)NC(=O)C(Cc1ccccc1)NC(=O)C(Cc...  10  AAAQ   generated
# 14  CC(O)C(Cc1ccccc1)NC(=O)C(Cc1ccccc1)NC(=O)C1C2C...  10  AABE   generated
# 15  CC(C)(C)NC(=O)C1CC2CCC(CC1C(=O)NC(Cc1ccccc1)C(...  10  AACB   generated
# 16  O=C(NC(Cc1ccccc1)C(=O)O)C1CC2CC(C1)C2C(=O)NC(C...  10  AABG   generated
# 17  O=C(O)C(Cc1ccccc1)NC(=O)C(Cc1ccccc1)C(=O)NC1CC...   9  AAAX   generated
# 18  O=C(NCC1(c2ccccn2)CC1)NC1CC2CCC(C1)C2C(=O)NC(C...  10  AABY   generated
# 19  O=C(NCC1(c2ccccn2)CC1)NC1CC2CC(C1)C2C(=O)NC(Cc...  10  AAAH   generated
# 20  O=C(NCC1(c2ccccc2)CC1)NC1CC2CCC(C1)C2C(=O)NC(C...  10  AAAC   generated
# 21  O=C(NCC1(c2ccccc2)CC1)NC1CC2CC(C1)C2C(=O)NC(Cc...  10  AAAG   generated
# 22  O=C(NCC1(N2CCCC2)CC1)NC1CC2CC(C1)C2C(=O)NC(Cc1...   9  AACZ   generated
# 23  O=C(NC1CC2CCC(C1)C2C(=O)NC(Cc1ccccc1)C(=O)NC(C...   9  AADY   generated
# 27  COC(=O)N1CC2CCC(CC1C(=O)NC(Cc1ccccc1)C(=O)O)C2...  10  AAAI   generated
# 26  O=C(O)C(Cc1ccccc1)NC(=O)C1CC2CCC(CC1C(=O)O)C2C...  10  AAAV   generated
# 24  CC(C)(C)NC(=O)C1CCC2CCC(C1)C2C(=O)NC(Cc1ccccc1...   9  AAAI   generated
# 25  CC(C)C(C)NC(=O)C1CC2CCC(CC1C(=O)NC(Cc1ccccc1)C...   9  AACX   generated
# 28  O=C(NC1CC2CC(C1)C2C(=O)NC(Cc1ccccc1)C(=O)NC(Cc...   9  AACK   generated
# 29  NC(=O)C1CC2CCC(CC1C(=O)NC(Cc1ccccc1)C(=O)O)C2C...   9  AABL   generated
# 30  CC(C)(C)NC(=O)C1CC2CCC(CC1C(=O)NC(Cc1ccccc1)C(...   9  AAES   generated
# 31  O=C(NC1CC2CC(C1)C2C(=O)NC(Cc1ccccc1)C(=O)NC(Cc...  10  AAAX   generated
# 32  CC(C)(C)NC(=O)C1CC2CCC(CC1C(=O)NC(Cc1ccccc1)C(...   9  AADI   generated
# 33  CC(C)(C)NC(=O)C1CC2CCC(CC1C(=O)NC(Cc1ccccc1)C(...   9  AAEF   generated
# 34  O=C(NC(Cc1ccccc1)C(=O)NC(Cc1ccccc1)C(=O)NC(Cc1...  10  AAAS   generated
# 35  O=C(NC1CC2CCCC21)C1CC2CC(C1)C2C(=O)NC(Cc1ccccc...   9  AAEU   generated
# 36  CC(C)(C)NC(=O)C1CC2CCC(CC1C(=O)NC(Cc1ccccc1)C(...   9  AABF   generated
# 37  O=C(NC1CCCC1)NC1CC2CCC(C1)C2C(=O)NC(Cc1ccccc1)...  10  AABO   generated
# 38  O=C(NC1CC2CCC(C1)N2CCc1ccc2ncccc2c1)C1CC2CC(C1...   9  AABR   generated
# 39  O=C(O)C(Cc1ccccc1)NC(=O)C(Cc1ccccc1)C(=O)NC1CC...   9  AAEK   generated
# 40  CC(C)(C)NC(=O)N1CC2CCC(CC1C(=O)NC(Cc1ccccc1)C(...   9  AAEG   generated
# 41  CCC(CC)COC(=O)C(C)NP(=O)(OCC1C(C(C(O1)(C#N)C2=...  11  AAAA  remdesivir
# 42  CC(C)(C)NC(=O)C1CC2CCCCC2CN1CC(O)C(Cc1ccccc1)N...   0  ABSI         hiv
# 43  CC(C)CN(CC(O)C(Cc1ccccc1)NC(=O)OC1COC2OCCC12)S...   0  ABSH         hiv
# 44  CC(C)CN(CC(O)C(Cc1ccccc1)NC(=O)OC1COC2OCCC12)S...   0  ABSK         hiv
# 45  COC(=O)NC(C(=O)NC(Cc1ccccc1)C(O)CN(Cc1ccc(-c2c...   0  ABSN         hiv
# 46  CC(C)(C)NC(=O)C1CN(Cc2cccnc2)CCN1CC(O)CC(Cc1cc...   0  ABSR         hiv
# 47  Cc1c(O)cccc1C(=O)NC(CSc1ccccc1)C(O)CN1CC2CCCCC...   0  ABSL         hiv
# 48  CCOP(=O)(COc1ccc(CC(NC(=O)OC2COC3OCCC23)C(O)CN...   0  ABSS         hiv
# 49  COC(=O)NC(C(=O)NCCCCC(CO)N(CC(C)C)S(=O)(=O)c1c...   0  ABST         hiv
#
#      weight  score_best  score_avg  similarity_to_hiv_inhibitors  \
# 0   786.926       -17.9 -16.075000                      0.375563
# 1   838.062       -17.7 -15.911111                      0.411519
# 2   867.104       -17.6 -15.555556                      0.422139
# 3   853.077       -17.6 -15.712500                      0.423334
# 4   839.050       -17.5 -15.677778                      0.426180
# 5   866.116       -17.5 -15.711111                      0.406250
# 6   852.089       -17.4 -15.722222                      0.408519
# 7   868.088       -17.3 -15.388889                      0.443731
# 8   852.089       -17.2 -15.611111                      0.408807
# 9   772.899       -17.2 -15.700000                      0.377883
# 10  825.023       -17.1 -15.333333                      0.425781
# 12  772.899       -17.0 -15.012500                      0.410245
# 11  771.915       -17.0 -15.000000                      0.408315
# 13  839.090       -16.9 -14.783333                      0.412792
# 14  772.943       -16.9 -15.025000                      0.426463
# 15  891.119       -16.7 -14.733333                      0.416525
# 16  772.899       -16.5 -14.780000                      0.381969
# 17  758.872       -16.5 -14.600000                      0.433272
# 18  784.958       -16.3 -14.511111                      0.429450
# 19  770.931       -16.3 -14.357143                      0.431268
# 20  783.970       -16.3 -14.511111                      0.406019
# 21  769.943       -16.2 -14.311111                      0.406846
# 22  762.952       -15.9 -13.977778                      0.411722
# 23  895.114       -15.7 -13.937500                      0.391144
# 27  851.010       -15.6 -14.188889                      0.474480
# 26  835.995       -15.6 -14.366667                      0.416469
# 24  895.114       -15.6 -13.600000                      0.435434
# 25  895.107       -15.6 -14.111111                      0.504767
# 28  733.910       -15.5 -13.450000                      0.392347
# 29  835.011       -15.5 -13.777778                      0.415378
# 30  883.052       -15.5 -13.666667                      0.492613
# 31  733.910       -15.4 -13.377778                      0.392943
# 32  881.080       -15.3 -13.733333                      0.505781
# 33  883.052       -15.2 -13.811111                      0.499153
# 34  772.899       -15.2 -13.566667                      0.381969
# 35  718.895       -15.1 -13.600000                      0.392526
# 36  752.909       -15.1 -13.766667                      0.386689
# 37  721.899       -15.1 -13.157143                      0.388273
# 38  741.933       -15.0 -13.588889                      0.436814
# 39  767.971       -14.0 -13.466667                      0.430805
# 40  882.068       -13.6 -13.033333                      0.516069
# 41  602.585       -13.5 -12.666667                      0.483767
# 42  670.855       -10.7  -9.633333                      0.513706
# 43  756.004        -9.9  -9.355556                      0.588024
# 44  547.674        -9.7  -8.655556                      0.592052
# 45  704.869        -9.1  -8.366667                      0.501215
# 46  613.803        -8.5  -8.133333                      0.474714
# 47  567.796        -8.1  -7.833333                      0.472333
# 48  728.798        -8.1  -7.733333                      0.585561
# 49  624.804        -7.9  -7.677778                      0.511851
#
#     similarity_to_remdesivir
# 0                   0.300506
# 1                   0.350693
# 2                   0.380663
# 3                   0.383214
# 4                   0.386439
# 5                   0.343143
# 6                   0.346644
# 7                   0.425683
# 8                   0.346837
# 9                   0.304666
# 10                  0.390728
# 12                  0.350304
# 11                  0.352159
# 13                  0.357697
# 14                  0.364842
# 15                  0.376659
# 16                  0.310500
# 17                  0.409586
# 18                  0.432018
# 19                  0.434759
# 20                  0.373687
# 21                  0.376796
# 22                  0.374447
# 23                  0.339654
# 27                  0.462121
# 26                  0.383425
# 24                  0.417763
# 25                  0.477482
# 28                  0.348165
# 29                  0.373200
# 30                  0.469122
# 31                  0.344098
# 32                  0.476423
# 33                  0.479245
# 34                  0.310500
# 35                  0.332776
# 36                  0.317647
# 37                  0.330357
# 38                  0.405495
# 39                  0.411507
# 40                  0.520945
# 41                  1.000000
# 42                  0.489396
# 43                  0.589407
# 44                  0.470364
# 45                  0.453570
# 46                  0.473684
# 47                  0.432787
# 48                  0.530075
# 49                  0.433820

# %%
new_table.to_csv(r'./generations/master_results_table_final.csv', index=False)
